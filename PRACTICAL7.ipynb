# %% [markdown]
# <a href="https://colab.research.google.com/github/345sarthak/Data-science-prc/blob/main/PRACTICAL7.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
df=pd.DataFrame (
               {"Roll no":[11,12,13,14,14],
                "Name":["sarthak","ritik","akash","Abhi","Abhi"],
                "Address":["vashi","panvel","kharghar","Nagar","Nagar"],
               "Marks":[40,50,30,20,20]
        }
)
print(df)
# Out:
#    Roll no     Name   Address  Marks
# 0       11  sarthak     vashi     40
# 1       12    ritik    panvel     50
# 2       13    akash  kharghar     30
# 3       14     Abhi     Nagar     20
# 4       14     Abhi     Nagar     20

# %%
df.isnull().sum
# Out:
# <bound method NDFrame._add_numeric_operations.<locals>.sum of    Roll no   Name  Address  Marks
# 0    False  False    False  False
# 1    False  False    False  False
# 2    False  False    False  False
# 3    False  False    False  False>

# %%
df.describe()
# Out:
#          Roll no      Marks
# count   4.000000   4.000000
# mean   12.500000  35.000000
# std     1.290994  12.909944
# min    11.000000  20.000000
# 25%    11.750000  27.500000
# 50%    12.500000  35.000000
# 75%    13.250000  42.500000
# max    14.000000  50.000000
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_0['Roll no'].plot(kind='hist', bins=20, title='Roll no')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_1['Marks'].plot(kind='hist', bins=20, title='Marks')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">2-d distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_2.plot(kind='scatter', x='Roll no', y='Marks', s=32, alpha=.8)
# ...

# %%
df.describe(include="object")
# Out:
#            Name Address
# count         4       4
# unique        4       4
# top     sarthak   vashi
# freq          1       1

# %%
df.shape
# Out:
# (4, 4)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4 entries, 0 to 3
# Data columns (total 4 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Roll no  4 non-null      int64
#  1   Name     4 non-null      object
#  2   Address  4 non-null      object
#  3   Marks    4 non-null      int64
# dtypes: int64(2), object(2)
# memory usage: 256.0+ bytes

# %%
df.duplicated()
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4     True
# dtype: bool

# %%
df.duplicated().sum()
# Out:
# 1

# %%
df.nunique()
# Out:
# Roll no    4
# Name       4
# Address    4
# Marks      4
# dtype: int64

# %%
df.value_counts()
# Out:
# Roll no  Name     Address   Marks
# 14       Abhi     Nagar     20       2
# 11       sarthak  vashi     40       1
# 12       ritik    panvel    50       1
# 13       akash    kharghar  30       1
# dtype: int64

# %%
df["Name"].value_counts()
# Out:
# Abhi       2
# sarthak    1
# ritik      1
# akash      1
# Name: Name, dtype: int64

# %%
df.corr()
# Out:
# <ipython-input-20-2f6f6606aa2c>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.corr()
#           Roll no     Marks
# Roll no  1.000000 -0.852941
# Marks   -0.852941  1.000000

# %%
import seaborn as sns
corres=df.corr()
sns.heatmap(corres,annot=True,cmap='coolwarm',fmt='.3f')
# Out:
# <ipython-input-25-e2d4ed60aebc>:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   corres=df.corr()
# <Axes: >

# %%
df.var()
# Out:
# <ipython-input-26-28ded241fd7c>:1: FutureWarning: The default value of numeric_only in DataFrame.var is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.var()
# Roll no      1.7
# Marks      170.0
# dtype: float64

# %%
df.mean()
# Out:
# <ipython-input-27-c61f0c8f89b5>:1: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.mean()
# Roll no    12.8
# Marks      32.0
# dtype: float64

# %%
df.min()
# Out:
# Roll no       11
# Name        Abhi
# Address    Nagar
# Marks         20
# dtype: object

# %%
df['Marks'].var()
# Out:
# 170.0

# %%
df.cov()
# Out:
# <ipython-input-31-6f98a29763d5>:1: FutureWarning: The default value of numeric_only in DataFrame.cov is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.cov()
#          Roll no  Marks
# Roll no      1.7  -14.5
# Marks      -14.5  170.0
